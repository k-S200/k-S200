# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly 
import warnings
warnings.filterwarnings('ignore')

# %%
da2=pd.read_csv('C:/Users/Saket sai/Documents/Predicting-Flight-Delays-Using-Local-Weather-Data-main/Predicting-Flight-Delays-Using-Local-Weather-Data-main/data/weather2.csv')

# %%
da2.head()
# Out:
#        STATION                                               NAME        DATE  \
# 0  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US  2015-01-01
# 1  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US  2015-01-02
# 2  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US  2015-01-03
# 3  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US  2015-01-04
# 4  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US  2015-01-05
#
#     AWND  PGTM  PRCP  SNOW  SNWD  TAVG  TMAX  ...  WSF2  WSF5  WT01  WT02  \
# 0  10.51   NaN  0.00   0.0   3.1    18    30  ...  19.9  25.9   NaN   NaN
# 1   6.93   NaN  0.00   0.0   3.1    17    28  ...  16.1  19.0   NaN   NaN
# 2  12.53   NaN  0.00   0.1   3.1    26    33  ...  29.1  35.1   1.0   NaN
# 3  16.11   NaN  0.00   0.0   3.1     5    12  ...  25.9  34.0   NaN   NaN
# 4   7.16   NaN  0.06   0.5   3.1    -7     1  ...  15.0  19.0   1.0   NaN
#
#    WT03  WT04  WT05  WT06  WT08  WT09
# ...

# %%
da2.tail()
# Out:
#          STATION                                        NAME        DATE  \
# 725  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  2015-12-27
# 726  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  2015-12-28
# 727  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  2015-12-29
# 728  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  2015-12-30
# 729  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  2015-12-31
#
#      AWND  PRCP  SNOW  SNWD  TAVG  TMAX  TMIN  WDF2   WDF5  WSF2  WSF5  WT01  \
# 725  4.47  0.01   0.0   0.0    42    48    34    90   90.0  15.0  17.0   1.0
# 726  5.14  0.11   0.0   0.0    44    48    41    10   10.0  13.0  15.0   1.0
# 727  2.91  0.00   0.0   0.0    44    54    36   250  250.0  12.1  13.0   1.0
# 728  6.93  0.01   0.0   0.0    46    49    40    60  360.0  16.1  18.1   1.0
# 729  8.05  0.00   0.0   0.0    46    51    39    80   70.0  17.0  19.9   1.0
#
#      WT08  WT09
# 725   1.0   1.0
# 726   1.0   1.0
# ...

# %%
da2.describe()
# Out:
#              AWND  PGTM        PRCP        SNOW        SNWD        TAVG  \
# count  730.000000   0.0  730.000000  365.000000  365.000000  730.000000
# mean     9.522192   NaN    0.061068    0.087671    0.432603   53.935616
# std      4.000793   NaN    0.226816    0.421648    1.027135   16.805919
# min      0.890000   NaN    0.000000    0.000000    0.000000   -7.000000
# 25%      6.710000   NaN    0.000000    0.000000    0.000000   49.000000
# 50%      9.170000   NaN    0.000000    0.000000    0.000000   57.000000
# 75%     12.080000   NaN    0.000000    0.000000    0.000000   64.000000
# max     24.610000   NaN    2.830000    3.800000    5.100000   83.000000
#
#              TMAX        TMIN        WDF2        WDF5        WSF2        WSF5  \
# count  730.000000  730.000000  730.000000  725.000000  730.000000  725.000000
# mean    62.419178   46.527397  231.178082  226.496552   20.868219   26.630621
# std     18.020859   16.815629   86.992004   92.583405    6.418590    7.800728
# ...

# %%
da2.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'PGTM', 'PRCP', 'SNOW', 'SNWD',
#        'TAVG', 'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5', 'WT01', 'WT02',
#        'WT03', 'WT04', 'WT05', 'WT06', 'WT08', 'WT09'],
#       dtype='object')

# %%
da2.shape
# Out:
# (730, 23)

# %%
da2.nunique()
# Out:
# STATION      2
# NAME         2
# DATE       365
# AWND        91
# PGTM         0
# PRCP        64
# SNOW        18
# SNWD         6
# TAVG        84
# TMAX        90
# TMIN        81
# WDF2        36
# WDF5        36
# WSF2        33
# WSF5        48
# WT01         1
# WT02         1
# WT03         1
# WT04         1
# WT05         0
# WT06         1
# WT08         1
# WT09         1
# dtype: int64

# %%
da2.drop(columns=[ 'PGTM', 'WT02', 'WT03', 'WT04', 'WT05', 'WT06'],inplace=True)

# %%
da2.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'PRCP', 'SNOW', 'SNWD', 'TAVG',
#        'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5', 'WT01', 'WT08', 'WT09'],
#       dtype='object')

# %%
da2['STATION'].unique()
# Out:
# array(['USW00014922', 'USW00023234'], dtype=object)

# %%
da2['TMAX'].unique()
# Out:
# array([30, 28, 33, 12,  1,  8, -1, 16,  6, 19, 14,  5, 15, 24, 35, 38, 39,
#        37, 32, 42, 45, 36, 31, 34, 27, 21, 29, 10,  9, 20,  2, 25,  0, 23,
#        11, 26, 44, 48, 57, 66, 58, 62, 61, 70, 46, 50, 56, 41, 53, 65, 84,
#        43, 52, 68, 75, 64, 72, 73, 60, 49, 55, 69, 80, 83, 77, 76, 67, 74,
#        63, 79, 81, 92, 71, 85, 78, 82, 86, 88, 89, 87, 90, 94, 91, 54, 59,
#        47, 51, 40, 22, 93], dtype=int64)

# %%
da2.isnull().sum()
# Out:
# STATION      0
# NAME         0
# DATE         0
# AWND         0
# PRCP         0
# SNOW       365
# SNWD       365
# TAVG         0
# TMAX         0
# TMIN         0
# WDF2         0
# WDF5         5
# WSF2         0
# WSF5         5
# WT01       490
# WT08       587
# WT09       725
# dtype: int64

# %%
#data['PGTM'].fillna(data['PGTM'].median(),inplace=True)
da2['SNOW'].fillna(da2['SNOW'].median(),inplace=True)
da2['SNWD'].fillna(da2['SNWD'].median(),inplace=True)
da2['WDF5'].fillna(da2['WDF5'].median(),inplace=True)
da2['WSF5'].fillna(da2['WSF5'].median(),inplace=True)
da2['WT01'].fillna(da2['WT01'].median(),inplace=True)
da2['WT08'].fillna(da2['WT08'].median(),inplace=True)
da2['WT09'].fillna(da2['WT09'].median(),inplace=True)

# %%
da2.isnull().sum()
# Out:
# STATION    0
# NAME       0
# DATE       0
# AWND       0
# PRCP       0
# SNOW       0
# SNWD       0
# TAVG       0
# TMAX       0
# TMIN       0
# WDF2       0
# WDF5       0
# WSF2       0
# WSF5       0
# WT01       0
# WT08       0
# WT09       0
# dtype: int64

# %%
corelation=da2.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
da2.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'PRCP', 'SNOW', 'SNWD', 'TAVG',
#        'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5', 'WT01', 'WT08', 'WT09'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['AWND'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['AWND'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['AWND'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['PRCP'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['PRCP'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['PRCP'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['SNOW'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['SNOW'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['SNOW'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['SNWD'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['SNWD'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['SNWD'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['TAVG'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['TAVG'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['TAVG'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['TMAX'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['TMAX'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['TMAX'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['TMIN'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['TMIN'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['TMIN'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['WDF2'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['WDF2'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['WDF2'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['WDF5'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['WDF5'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['WDF5'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['WSF2'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['WSF2'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['WSF2'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['WSF5'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['WSF5'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['WSF5'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['WT01'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['WT01'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['WT01'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['WT08'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['WT08'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['WT08'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(da2['WT09'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(da2['WT09'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(da2['WT09'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()
