# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly 
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('C:/Users/Saket sai/Documents/Predicting-Flight-Delays-Using-Local-Weather-Data-main/Predicting-Flight-Delays-Using-Local-Weather-Data-main/data/weather1.csv')

# %%
data.head()
# Out:
#        STATION                       NAME        DATE  AWND  PGTM  PRCP  SNOW  \
# 0  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-01  2.01   NaN  0.00   0.0
# 1  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-02  3.36   NaN  0.00   0.0
# 2  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-03  3.36   NaN  0.00   0.0
# 3  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-04  1.12   NaN  0.02   0.1
# 4  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-05  3.58   NaN  0.11   0.1
#
#    SNWD  TAVG  TMAX  ...  WT01  WT02  WT03  WT04  WT05  WT06  WT07  WT08  \
# 0   3.1  12.0  18.0  ...   1.0   NaN   NaN   NaN   NaN   NaN   NaN   1.0
# 1   3.1  13.0  20.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   2.0  17.0  25.0  ...   1.0   NaN   NaN   NaN   NaN   NaN   NaN   1.0
# 3   2.0  23.0  32.0  ...   1.0   NaN   NaN   NaN   NaN   1.0   NaN   1.0
# 4   3.1  31.0  39.0  ...   1.0   1.0   NaN   NaN   NaN   1.0   NaN   NaN
#
#    WT09  WT10
# 0   NaN   NaN
# 1   NaN   NaN
# ...

# %%
data.tail()
# Out:
#            STATION                                        NAME        DATE  \
# 21159  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2015-12-27
# 21160  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2015-12-28
# 21161  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2015-12-29
# 21162  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2015-12-30
# 21163  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2015-12-31
#
#         AWND  PGTM  PRCP  SNOW  SNWD  TAVG  TMAX  ...  WT01  WT02  WT03  WT04  \
# 21159  17.22   NaN  0.14   0.0   0.0  38.0  40.0  ...   1.0   NaN   NaN   NaN
# 21160  19.01   NaN  1.47   1.9   0.0  33.0  39.0  ...   1.0   NaN   NaN   1.0
# 21161  11.41   NaN  0.00   0.0   1.2  33.0  39.0  ...   1.0   NaN   NaN   NaN
# 21162   8.72   NaN  0.09   1.1   1.2  29.0  29.0  ...   1.0   NaN   NaN   NaN
# 21163  13.42   NaN  0.00   0.0   1.0  26.0  28.0  ...   NaN   NaN   NaN   NaN
#
#        WT05  WT06  WT07  WT08  WT09  WT10
# ...

# %%
data.describe()
# Out:
#                AWND         PGTM          PRCP          SNOW          SNWD  \
# count  20803.000000  1128.000000  21163.000000  15706.000000  15000.000000
# mean       8.088918  1309.884752      0.111890      0.079288      0.499820
# std        3.642919   617.796994      0.354276      0.613624      3.051514
# min        0.000000     0.000000      0.000000      0.000000      0.000000
# 25%        5.590000  1005.750000      0.000000      0.000000      0.000000
# 50%        7.380000  1345.000000      0.000000      0.000000      0.000000
# 75%       10.070000  1724.000000      0.030000      0.000000      0.000000
# max       27.740000  2359.000000      8.670000     22.100000     48.800000
#
#                TAVG          TMAX          TMIN        TOBS          WDF2  \
# count  19164.000000  21162.000000  21158.000000  352.000000  20803.000000
# mean      60.777865     70.212362     51.379525   57.309659    195.890977
# ...

# %%
data.shape
# Out:
# (21164, 26)

# %%
data.nunique()
# Out:
# STATION     58
# NAME        58
# DATE       365
# AWND       117
# PGTM       726
# PRCP       293
# SNOW        86
# SNWD        49
# TAVG       109
# TMAX       116
# TMIN       113
# TOBS        32
# WDF2        36
# WDF5        36
# WSF2        49
# WSF5        68
# WT01         1
# WT02         1
# WT03         1
# WT04         1
# WT05         1
# WT06         1
# WT07         1
# WT08         1
# WT09         1
# WT10         1
# dtype: int64

# %%
data.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'PGTM', 'PRCP', 'SNOW', 'SNWD',
#        'TAVG', 'TMAX', 'TMIN', 'TOBS', 'WDF2', 'WDF5', 'WSF2', 'WSF5', 'WT01',
#        'WT02', 'WT03', 'WT04', 'WT05', 'WT06', 'WT07', 'WT08', 'WT09', 'WT10'],
#       dtype='object')

# %%
data['STATION'].unique()
# Out:
# array(['USW00024131', 'USW00024132', 'USW00023160', 'USW00014606',
#        'USW00023169', 'USW00014732', 'USW00014733', 'USW00014734',
#        'USW00014933', 'USW00013967', 'USW00013889', 'USW00003947',
#        'USW00093225', 'USW00093821', 'USC00046336', 'USW00023174',
#        'USW00012839', 'USW00012916', 'USW00023050', 'USW00013968',
#        'USW00021510', 'USW00024229', 'USW00014739', 'USW00014819',
#        'USW00022521', 'USW00093814', 'USW00013893', 'USW00014820',
#        'USW00014942', 'USW00014821', 'USW00093819', 'USW00021504',
#        'USW00025309', 'USW00093730', 'USW00012844', 'USW00012921',
#        'USW00012842', 'USW00013897', 'USW00094823', 'USW00094789',
#        'USW00012960', 'USW00024233', 'USW00024153', 'USW00023188',
#        'USW00024033', 'USW00003017', 'USW00013739', 'USW00023183',
#        'USW00093805', 'USW00003927', 'USW00093721', 'USW00013743',
#        'USW00012815', 'USW00024127', 'USW00013874', 'USW00094847',
# ...

# %%
data['WT04'].unique()
# Out:
# array([nan,  1.])

# %%
data['WT04'].unique()
# Out:
# array([nan,  1.])

# %%
data.drop(columns=['PGTM', 'TOBS', 'WT03','WT04', 'WT05', 'WT06','WT07', 'WT08', 'WT09', 'WT10'],inplace=True)

# %%
data.head()
# Out:
#        STATION                       NAME        DATE  AWND  PRCP  SNOW  SNWD  \
# 0  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-01  2.01  0.00   0.0   3.1
# 1  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-02  3.36  0.00   0.0   3.1
# 2  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-03  3.36  0.00   0.0   2.0
# 3  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-04  1.12  0.02   0.1   2.0
# 4  USW00024131  BOISE AIR TERMINAL, ID US  2015-01-05  3.58  0.11   0.1   3.1
#
#    TAVG  TMAX  TMIN   WDF2   WDF5  WSF2  WSF5  WT01  WT02
# 0  12.0  18.0   6.0  130.0  140.0   8.9  13.0   1.0   NaN
# 1  13.0  20.0   8.0  130.0  130.0   8.9  12.1   NaN   NaN
# 2  17.0  25.0  12.0  130.0  230.0  10.1  16.1   1.0   NaN
# 3  23.0  32.0  19.0  340.0  190.0   8.9  12.1   1.0   NaN
# 4  31.0  39.0  29.0   90.0  300.0  12.1  17.0   1.0   1.0

# %%
data.mode()
# Out:
#          STATION                                               NAME  \
# 0    USW00003017           ALBUQUERQUE INTERNATIONAL AIRPORT, NM US
# 1    USW00003927  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 2    USW00003947         ATLANTIC CITY INTERNATIONAL AIRPORT, NJ US
# 3    USW00012815  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 4    USW00012839                BANGOR INTERNATIONAL AIRPORT, ME US
# ..           ...                                                ...
# 354          NaN                                                NaN
# 355          NaN                                                NaN
# 356          NaN                                                NaN
# 357          NaN                                                NaN
# 358          NaN                                                NaN
#
#            DATE  AWND  PRCP  SNOW  SNWD  TAVG  TMAX  TMIN   WDF2   WDF5  WSF2  \
# ...

# %%
data.isnull().sum()
# Out:
# STATION        0
# NAME           0
# DATE           0
# AWND         361
# PRCP           1
# SNOW        5458
# SNWD        6164
# TAVG        2000
# TMAX           2
# TMIN           6
# WDF2         361
# WDF5         507
# WSF2         361
# WSF5         506
# WT01       13732
# WT02       20212
# dtype: int64

# %%
data.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'PRCP', 'SNOW', 'SNWD', 'TAVG',
#        'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5', 'WT01', 'WT02'],
#       dtype='object')

# %%
#data['STATION'].fillna(data['STATION'].median(),inplace=True)
#data['NAME'].fillna(data['NAME'].median(),inplace=True)
#data['DATE'].fillna(data['DATE'].median(),inplace=True)
data['AWND'].fillna(data['AWND'].median(),inplace=True)
data['PRCP'].fillna(data['PRCP'].median(),inplace=True)
data['SNOW'].fillna(data['SNOW'].median(),inplace=True)
data['SNWD'].fillna(data['SNWD'].median(),inplace=True)
data['TAVG'].fillna(data['TAVG'].median(),inplace=True)
data['TMAX'].fillna(data['TMAX'].median(),inplace=True)
data['TMIN'].fillna(data['TMIN'].median(),inplace=True)
data['WDF2'].fillna(data['WDF2'].median(),inplace=True)
data['WDF5'].fillna(data['WDF5'].median(),inplace=True)
data['WSF5'].fillna(data['WSF5'].median(),inplace=True)
data['WSF2'].fillna(data['WSF2'].median(),inplace=True)
data['WT01'].fillna(data['WT01'].median(),inplace=True)
data['WT02'].fillna(data['WT02'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# STATION    0
# NAME       0
# DATE       0
# AWND       0
# PRCP       0
# SNOW       0
# SNWD       0
# TAVG       0
# TMAX       0
# TMIN       0
# WDF2       0
# WDF5       0
# WSF2       0
# WSF5       0
# WT01       0
# WT02       0
# dtype: int64

# %%
#relationship analysis

# %%
corelation = data.corr()

# %%
print
# Out:
# <function print>

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'PRCP', 'SNOW', 'SNWD', 'TAVG',
#        'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5', 'WT01', 'WT02'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['AWND'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['AWND'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['AWND'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['PRCP'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['PRCP'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['PRCP'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['SNOW'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['SNOW'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['SNOW'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['SNWD'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['SNWD'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['SNWD'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['TAVG'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['TAVG'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['TAVG'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['TMAX'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['TMAX'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['TMAX'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['TMIN'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['TMIN'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['TMIN'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['WDF2'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['WDF2'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['WDF2'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['WDF5'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['WDF5'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['WDF5'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['WSF2'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['WSF2'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['WSF2'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['WSF5'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['WSF5'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['WSF5'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['WT01'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['WT01'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['WT01'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1, 3, 1)  # row 1, col 2 index 1
sns.distplot(data['WT02'])
plt.title('Distribution')
plt.subplot(1, 3, 2)
sns.histplot(data['WT02'])
plt.title('Histogram')
plt.subplot(1, 3, 3)
sns.boxplot(data['WT02'])
plt.title('Boxplot')
plt.tight_layout()
plt.show()
