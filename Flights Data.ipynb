# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns 
import plotly

# %%
data = pd.read_csv('C:/Users/Saket sai/Desktop/Flights datasets/flights.csv')
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# data.head()

# %%
data.tail()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# ...

# %%
data.shape
# Out:
# (5819079, 31)

# %%
data.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %%
data.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
data.nunique()
# Out:
# YEAR                      1
# MONTH                    12
# DAY                      31
# DAY_OF_WEEK               7
# AIRLINE                  14
# FLIGHT_NUMBER          6952
# TAIL_NUMBER            4897
# ORIGIN_AIRPORT          930
# DESTINATION_AIRPORT     930
# SCHEDULED_DEPARTURE    1321
# DEPARTURE_TIME         1440
# DEPARTURE_DELAY        1217
# TAXI_OUT                184
# WHEELS_OFF             1440
# SCHEDULED_TIME          550
# ELAPSED_TIME            712
# AIR_TIME                675
# DISTANCE               1363
# WHEELS_ON              1440
# TAXI_IN                 185
# SCHEDULED_ARRIVAL      1435
# ARRIVAL_TIME           1440
# ARRIVAL_DELAY          1240
# DIVERTED                  2
# CANCELLED                 2
# CANCELLATION_REASON       4
# AIR_SYSTEM_DELAY        570
# SECURITY_DELAY          154
# AIRLINE_DELAY          1067
# LATE_AIRCRAFT_DELAY     695
# WEATHER_DELAY           632
# dtype: int64

# %%
data['FLIGHT_NUMBER'].unique()
# Out:
# array([  98, 2336,  840, ..., 6777, 6895, 6887], dtype=int64)

# %%
data['TAXI_OUT'].unique()
# Out:
# array([ 21.,  12.,  16.,  15.,  11.,  18.,  13.,  17.,  28.,  25.,   9.,
#         30.,  14.,  10.,  nan,  43.,  24.,  19.,  22.,  23.,  37.,  31.,
#          7.,  32.,  26.,  33.,  42.,  27.,  20.,  38.,   4.,  29.,   8.,
#         41.,  56.,  48.,  40.,  34.,   3.,  36.,  61.,  35.,   6.,  45.,
#         39.,  46.,  62.,  49.,   5.,  57.,  64.,  63.,  47.,  54.,  55.,
#         44.,  59.,  50.,  76., 113.,  73.,  58.,  52.,   2.,  72.,  51.,
#        110.,  53.,  75.,  84.,  77.,  82.,  70., 105.,  69.,  71.,  81.,
#         66.,  80.,  99.,  60.,  74.,  95.,  89., 136., 131.,  79.,  68.,
#        120.,  67.,  88.,   1.,  65., 176., 160., 104., 111., 112.,  83.,
#         85., 121., 100.,  91.,  97.,  93.,  87., 129.,  92.,  90.,  98.,
#        107., 124., 146.,  86.,  78., 115., 103.,  94., 101., 102., 126.,
#        116., 132., 118., 106., 130., 109., 114., 128.,  96., 141., 125.,
#        149., 147., 122., 117., 108., 119., 137., 133., 135., 169., 152.,
# ...

# %%
data['CANCELLED'].value_counts()
# Out:
# 0    5729195
# 1      89884
# Name: CANCELLED, dtype: int64

# %%
data['DEPARTURE_TIME'].value_counts()
# Out:
# 555.0    14829
# 556.0    13976
# 557.0    13616
# 558.0    12954
# 655.0    12391
#          ...
# 353.0        6
# 338.0        6
# 438.0        4
# 433.0        3
# 403.0        3
# Name: DEPARTURE_TIME, Length: 1440, dtype: int64

# %%
data.drop(columns=['AIR_SYSTEM_DELAY','SECURITY_DELAY','AIRLINE_DELAY','LATE_AIRCRAFT_DELAY','WEATHER_DELAY','CANCELLATION_REASON' ,'CANCELLED','DIVERTED'],inplace=True)

# %%
data.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  WHEELS_OFF  \
# 0            ANC                 SEA                    5  ...        15.0
# 1            LAX                 PBI                   10  ...        14.0
# 2            SFO                 CLT                   20  ...        34.0
# 3            LAX                 MIA                   20  ...        30.0
# 4            SEA                 ANC                   25  ...        35.0
#
#    SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# ...

# %%
data.tail()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# ...

# %%
data.mode()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      7    2            4      WN            469      N480HA
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  WHEELS_OFF  \
# 0            ATL                 ATL                  600  ...       610.0
#
#    SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# 0            85.0          80.0      64.0       337     2045.0      5.0
#
#    SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY
# 0               2100        1645.0           -8.0
#
# [1 rows x 23 columns]

# %%
data['TAIL_NUMBER'].fillna('N480HA',inplace=True)

# %%
data['DEPARTURE_TIME'].fillna(data['DEPARTURE_TIME'].mean(),inplace=True)

# %%
data['DEPARTURE_DELAY'].fillna(data['DEPARTURE_DELAY'].mean(),inplace=True)

# %%
data['TAXI_OUT'].fillna(data['TAXI_OUT'].mean(),inplace=True)

# %%
data['WHEELS_OFF'].fillna(data['WHEELS_OFF'].mean(),inplace=True)

# %%
data['SCHEDULED_TIME'].fillna(data['SCHEDULED_DEPARTURE'].mean(),inplace=True)

# %%
data['ELAPSED_TIME'].fillna(data['ELAPSED_TIME'].mean(),inplace=True)

# %%
data['AIR_TIME'].fillna(data['AIR_TIME'].mean(),inplace=True)

# %%
data['WHEELS_ON'].fillna(data['WHEELS_ON'].mean(),inplace=True)

# %%
data['TAXI_IN'].fillna(data['TAXI_IN'].mean(),inplace=True)

# %%
data['ARRIVAL_TIME'].fillna(data['SCHEDULED_ARRIVAL'],inplace=True)

# %%
data['ARRIVAL_DELAY'].fillna(data['ARRIVAL_DELAY'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# YEAR                   0
# MONTH                  0
# DAY                    0
# DAY_OF_WEEK            0
# AIRLINE                0
# FLIGHT_NUMBER          0
# TAIL_NUMBER            0
# ORIGIN_AIRPORT         0
# DESTINATION_AIRPORT    0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_TIME         0
# DEPARTURE_DELAY        0
# TAXI_OUT               0
# WHEELS_OFF             0
# SCHEDULED_TIME         0
# ELAPSED_TIME           0
# AIR_TIME               0
# DISTANCE               0
# WHEELS_ON              0
# TAXI_IN                0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_TIME           0
# ARRIVAL_DELAY          0
# dtype: int64

# %%
#relationship analysis

# %%
corelation = data.corr()

# %%
print(corelation)
# Out:
#                      YEAR     MONTH       DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# YEAR                  NaN       NaN       NaN          NaN            NaN
# MONTH                 NaN  1.000000  0.008874    -0.007847      -0.020746
# DAY                   NaN  0.008874  1.000000     0.001111       0.001855
# DAY_OF_WEEK           NaN -0.007847  0.001111     1.000000       0.014461
# FLIGHT_NUMBER         NaN -0.020746  0.001855     0.014461       1.000000
# SCHEDULED_DEPARTURE   NaN  0.000207 -0.001647     0.008007      -0.005485
# DEPARTURE_TIME        NaN -0.004045 -0.002621     0.005558      -0.001432
# DEPARTURE_DELAY       NaN -0.021779 -0.000174    -0.011409      -0.008591
# TAXI_OUT              NaN -0.012986 -0.002638    -0.020452       0.049925
# WHEELS_OFF            NaN -0.004896 -0.003289     0.004023       0.005243
# SCHEDULED_TIME        NaN  0.010769  0.003397     0.014961      -0.317369
# ELAPSED_TIME          NaN  0.001850  0.001405     0.011389      -0.303422
# ...

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  WHEELS_OFF  \
# 0            ANC                 SEA                    5  ...        15.0
# 1            LAX                 PBI                   10  ...        14.0
# 2            SFO                 CLT                   20  ...        34.0
# 3            LAX                 MIA                   20  ...        30.0
# 4            SEA                 ANC                   25  ...        35.0
#
#    SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# ...

# %%
sns.distplot(data['FLIGHT_NUMBER'])
#sns.distplot( data['AIR_TIME'])
#sns.distplot( data['ARRIVAL_DELAY'])
#sns.distplot( data['ARRIVAL_TIME'])
#sns.distplot( data['DEPARTURE_DELAY'])
#sns.distplot( data['DEPARTURE_TIME'])
#sns.distplot( data['DISTANCE'])
#sns.distplot( data['ELAPSED_TIME'])
#sns.distplot( data['SCHEDULED_ARRIVAL'])
#sns.distplot( data['SCHEDULED_DEPARTURE'])
#sns.distplot( data['SCHEDULED_TIME'])
#sns.distplot( data['TAXI_IN'] )
#sns.distplot( data['TAXI_OUT'])
#sns.distplot( data['WHEELS_OFF'])
#sns.distplot( data['WHEELS_ON'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='FLIGHT_NUMBER', ylabel='Density'>

# %%
sns.distplot( data['AIR_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AIR_TIME', ylabel='Density'>

# %%
sns.distplot( data['ARRIVAL_DELAY'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ARRIVAL_DELAY', ylabel='Density'>

# %%
sns.distplot( data['ARRIVAL_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ARRIVAL_TIME', ylabel='Density'>

# %%
sns.distplot( data['DEPARTURE_DELAY'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DEPARTURE_DELAY', ylabel='Density'>

# %%
sns.distplot( data['DEPARTURE_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DEPARTURE_TIME', ylabel='Density'>

# %%
sns.distplot( data['DISTANCE'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DISTANCE', ylabel='Density'>

# %%
sns.distplot( data['ELAPSED_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ELAPSED_TIME', ylabel='Density'>

# %%
sns.distplot( data['SCHEDULED_ARRIVAL'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SCHEDULED_ARRIVAL', ylabel='Density'>

# %%
sns.distplot( data['SCHEDULED_DEPARTURE'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SCHEDULED_DEPARTURE', ylabel='Density'>

# %%
sns.distplot( data['SCHEDULED_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SCHEDULED_TIME', ylabel='Density'>

# %%
sns.distplot( data['TAXI_IN'] )
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TAXI_IN', ylabel='Density'>

# %%
sns.distplot( data['TAXI_OUT'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TAXI_OUT', ylabel='Density'>

# %%
sns.distplot( data['WHEELS_OFF'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='WHEELS_OFF', ylabel='Density'>

# %%
data.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY'],
#       dtype='object')

# %%
sns.histplot(data['YEAR'])
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='Count'>

# %%
sns.boxplot(data['YEAR'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YEAR'>

# %%
sns.histplot(data['MONTH'])
# Out:
# <AxesSubplot:xlabel='MONTH', ylabel='Count'>

# %%
sns.boxplot(data['MONTH'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MONTH'>

# %%
sns.histplot(data['DAY'])
# Out:
# <AxesSubplot:xlabel='DAY', ylabel='Count'>

# %%
sns.boxplot(data['DAY'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DAY'>

# %%
sns.histplot(data['DAY_OF_WEEK'])
# Out:
# <AxesSubplot:xlabel='DAY_OF_WEEK', ylabel='Count'>

# %%
sns.boxplot(data['DAY_OF_WEEK'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DAY_OF_WEEK'>

# %%
sns.histplot(data['FLIGHT_NUMBER'])
# Out:
# <AxesSubplot:xlabel='FLIGHT_NUMBER', ylabel='Count'>

# %%
sns.boxplot(data['FLIGHT_NUMBER'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FLIGHT_NUMBER'>

# %%
sns.histplot(data['SCHEDULED_DEPARTURE'])
# Out:
# <AxesSubplot:xlabel='SCHEDULED_DEPARTURE', ylabel='Count'>

# %%
sns.boxplot(data['SCHEDULED_DEPARTURE'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SCHEDULED_DEPARTURE'>

# %%
sns.histplot(data['DEPARTURE_TIME'])
# Out:
# <AxesSubplot:xlabel='DEPARTURE_TIME', ylabel='Count'>

# %%
sns.boxplot(data['DEPARTURE_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DEPARTURE_TIME'>

# %%
sns.histplot(data['DEPARTURE_DELAY'])
# Out:
# <AxesSubplot:xlabel='DEPARTURE_DELAY', ylabel='Count'>

# %%
sns.boxplot(data['DEPARTURE_DELAY'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DEPARTURE_DELAY'>

# %%
sns.histplot(data['TAXI_OUT'])
# Out:
# <AxesSubplot:xlabel='TAXI_OUT', ylabel='Count'>

# %%
sns.boxplot(data['TAXI_OUT'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TAXI_OUT'>

# %%
sns.histplot(data['WHEELS_OFF'])
# Out:
# <AxesSubplot:xlabel='WHEELS_OFF', ylabel='Count'>

# %%
sns.boxplot(data['WHEELS_OFF'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='WHEELS_OFF'>

# %%
sns.histplot(data['SCHEDULED_TIME'])
# Out:
# <AxesSubplot:xlabel='SCHEDULED_TIME', ylabel='Count'>

# %%
sns.boxplot(data['SCHEDULED_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SCHEDULED_TIME'>

# %%
sns.histplot(data[ 'ELAPSED_TIME'])
# Out:
# <AxesSubplot:xlabel='ELAPSED_TIME', ylabel='Count'>

# %%
sns.boxplot(data[ 'ELAPSED_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ELAPSED_TIME'>

# %%
sns.histplot(data['AIR_TIME'])
# Out:
# <AxesSubplot:xlabel='AIR_TIME', ylabel='Count'>

# %%
sns.boxplot(data['AIR_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AIR_TIME'>

# %%
sns.histplot(data['DISTANCE'])
# Out:
# <AxesSubplot:xlabel='DISTANCE', ylabel='Count'>

# %%
sns.boxplot(data['DISTANCE'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DISTANCE'>

# %%
sns.histplot(data['WHEELS_ON'])
# Out:
# <AxesSubplot:xlabel='WHEELS_ON', ylabel='Count'>

# %%
sns.boxplot(data['WHEELS_ON'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='WHEELS_ON'>

# %%
sns.histplot(data['TAXI_IN'])
# Out:
# <AxesSubplot:xlabel='TAXI_IN', ylabel='Count'>

# %%
sns.boxplot(data['TAXI_IN'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TAXI_IN'>

# %%
sns.histplot(data[ 'SCHEDULED_ARRIVAL'])
# Out:
# <AxesSubplot:xlabel='SCHEDULED_ARRIVAL', ylabel='Count'>

# %%
sns.boxplot(data[ 'SCHEDULED_ARRIVAL'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SCHEDULED_ARRIVAL'>

# %%
sns.histplot(data[ 'ARRIVAL_TIME'])
# Out:
# <AxesSubplot:xlabel='ARRIVAL_TIME', ylabel='Count'>

# %%
sns.boxplot(data[ 'ARRIVAL_TIME'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ARRIVAL_TIME'>

# %%
sns.histplot(data['ARRIVAL_DELAY'])
# Out:
# <AxesSubplot:xlabel='ARRIVAL_DELAY', ylabel='Count'>

# %%
sns.boxplot(data['ARRIVAL_DELAY'])
# Out:
# C:\Users\Saket sai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ARRIVAL_DELAY'>
